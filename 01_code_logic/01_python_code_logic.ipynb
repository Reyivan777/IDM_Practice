# %% [markdown]
# # Practice 01 — Understanding Python Code Logic
#
# The goal of this notebook is **not** to write a large program. It is to train the skill of reading code, following data through it, predicting behavior, and translating an idea into code.
#
# ## Rules for this practice
#
# 1. **Predict before running.** If an exercise gives you code, first write what you think will happen.
# 2. Explain important steps in your own words. Avoid answers like “because Python does it”.
# 3. Do not use `pandas`, NumPy, `math.dist`, or AI-generated solutions unless an exercise explicitly allows it.
# 4. After completing an exercise, run the provided checks when available.
# 5. If your answer is wrong, do not immediately replace it. Write one sentence explaining **why your original reasoning failed**.
#
# There is no need to finish everything in one sitting.

# %% [markdown]
# ## Exercise 1 — Trace the execution
#
# **Do not run the next cell yet.**
#
# Read it line by line and determine:
#
# - What is the final value of `score`?
# - What is stored in `kept`?
# - For every number, explain what changes in `score`.
# - At exactly what iterations does the second `if` become true?
#
# Write your prediction in the markdown cell below, then run the code and compare.

# %%
numbers = [8, 3, 12, 5, 7, 10]

score = 0
kept = []

for n in numbers:
    if n % 2 == 0:
        score += n // 2
    else:
        score -= 1

    if score >= 8:
        kept.append((n, score))

print("score:", score)
print("kept:", kept)

# %% [markdown]
# ### My prediction
#
# - Final `score`:
# - Final `kept`:
# - Step-by-step reasoning:
#
# ### After running
#
# - Was my prediction correct?
# - If not, what did I misunderstand?

# %% [markdown]
# ## Exercise 2 — Understand data flow through a function
#
# Again, **reason before running**.
#
# Study the function below.
#
# 1. What does `low` represent?
# 2. What does `span` represent?
# 3. What will the function return for `[10, 20, 30]`?
# 4. Why is `(x - low) / span` used instead of simply `x / span`?
# 5. What problem occurs if the input is `[5, 5, 5]`?
# 6. Modify the function so that a constant list returns a list of zeros instead of failing.

# %%
def scale_0_1(values):
    low = min(values)
    high = max(values)
    span = high - low

    scaled = []
    for x in values:
        scaled.append((x - low) / span)

    return scaled

# Do not uncomment until you have made your predictions.
# print(scale_0_1([10, 20, 30]))
# print(scale_0_1([5, 5, 5]))

# %%
# Write your corrected version here.

def scale_0_1_safe(values):
    pass

# %%
# Run this only after implementing scale_0_1_safe.

assert scale_0_1_safe([10, 20, 30]) == [0.0, 0.5, 1.0]
assert scale_0_1_safe([5, 5, 5]) == [0, 0, 0]
print("Exercise 2 checks passed.")

# %% [markdown]
# ## Exercise 3 — References, copies, and mutation
#
# This is a common source of bugs in Python.
#
# **Predict the three printed lists before running the cell.** Then explain why `a`, `b`, and `c` do or do not change together.
#
# Afterward, change only one line so that modifying `b` no longer changes `a`.

# %%
a = [1, 2, 3]
b = a
c = a.copy()

b.append(4)
c[0] = 99

print("a:", a)
print("b:", b)
print("c:", c)

# %% [markdown]
# ### My explanation
#
# - `a`:
# - `b`:
# - `c`:
# - Why:
# - One-line change that would make `b` independent from `a`:

# %% [markdown]
# ## Exercise 4 — Clean data without pandas
#
# The point here is to understand the logic that libraries later automate for you.
#
# You have customer records with inconsistent text and invalid sales values.
#
# Create a new list called `clean_records` that:
#
# - removes leading/trailing spaces from `customer`;
# - converts the customer name to title case;
# - converts `country` to uppercase;
# - keeps only records where `sales` is greater than `0`;
# - does **not** modify `raw_records`.
#
# Then calculate:
#
# - the total sales in the cleaned data;
# - the number of valid records from each country.
#
# Use loops, conditionals, dictionaries, and list operations only.

# %%
raw_records = [
    {"customer": "  alpha tools ", "country": "mx", "sales": 1200},
    {"customer": "BETA INDUSTRIES", "country": "us", "sales": 850},
    {"customer": " gamma metals", "country": "mx", "sales": -50},
    {"customer": "Delta systems  ", "country": "ca", "sales": 430},
    {"customer": " epsilon parts ", "country": "us", "sales": 0},
]

# Your code here

clean_records = []
country_counts = {}
total_sales = 0

# %%
# Run after completing Exercise 4.

assert raw_records[0]["customer"] == "  alpha tools "
assert len(clean_records) == 3
assert total_sales == 2480
assert country_counts == {"MX": 1, "US": 1, "CA": 1}
print("Exercise 4 checks passed.")

# %% [markdown]
# ## Exercise 5 — Turn a mathematical definition into code
#
# Write a function called `euclidean_distance(p1, p2)` for two-dimensional points.
#
# For points
#
# \[
# p_1=(x_1,y_1), \qquad p_2=(x_2,y_2)
# \]
#
# use
#
# \[
# d(p_1,p_2)=\sqrt{(x_1-x_2)^2+(y_1-y_2)^2}.
# \]
#
# ### Restrictions
#
# - Do not use NumPy.
# - Do not use `math.dist`.
# - You may use `** 0.5` for the square root.
#
# Before coding, write the sequence of operations Python has to perform. The important part is translating the formula into an algorithm.

# %% [markdown]
# ### Algorithm in my own words
#
# 1.
# 2.
# 3.
# 4.

# %%
def euclidean_distance(p1, p2):
    # Your code here
    pass

# %%
assert euclidean_distance((0, 0), (3, 4)) == 5
assert euclidean_distance((2, 1), (2, 1)) == 0
assert round(euclidean_distance((1, 2), (4, 6)), 5) == 5
print("Exercise 5 checks passed.")

# %% [markdown]
# ## Exercise 6 — Build a tiny clustering step from scratch
#
# Now use your distance function instead of jumping directly to a clustering library.
#
# For every point below:
#
# 1. Calculate its distance to centroid `A`.
# 2. Calculate its distance to centroid `B`.
# 3. Assign the point to whichever centroid is closer.
# 4. Store the result in a dictionary called `assignments`.
#
# The expected structure is:
#
# ```python
# {
#     (1, 2): "A",
#     ...
# }
# ```
#
# Do **not** hard-code the answers. Your code should work if the points or centroids change.

# %%
points = [(1, 2), (2, 1), (7, 8), (8, 7), (4, 5)]
centroids = {
    "A": (2, 2),
    "B": (7, 7)
}

assignments = {}

# Your code here

# %%
assert assignments == {
    (1, 2): "A",
    (2, 1): "A",
    (7, 8): "B",
    (8, 7): "B",
    (4, 5): "B",
}
print("Exercise 6 checks passed.")

# %% [markdown]
# ### Explain your logic
#
# Without describing syntax line by line, explain the algorithm:
#
# - What information is available at the beginning of each iteration?
# - What quantities must be calculated?
# - What decision is made?
# - What information is stored for later?
#
# Then answer: **Which part of this exercise resembles the assignment step in k-means?**

# %% [markdown]
# ## Exercise 7 — Debug logic, not syntax
#
# The function below is supposed to calculate the average of only the **positive** values in a list.
#
# It runs without a syntax error, but its logic is wrong.
#
# 1. Find the logical problem(s).
# 2. Give an input for which the bug becomes obvious.
# 3. Correct the function.
# 4. Explain why your correction works.

# %%
def positive_average(values):
    total = 0

    for x in values:
        if x >= 0:
            total += x

    return total / len(values)


print(positive_average([-5, 10, 20]))

# %%
# Write your corrected function here.

def positive_average_fixed(values):
    pass

# %%
assert positive_average_fixed([-5, 10, 20]) == 15
assert positive_average_fixed([1, 2, 3]) == 2
print("Basic Exercise 7 checks passed.")

# Extra question:
# What should your function do if there are no positive values?
# Decide on a behavior and modify the function accordingly.

# %% [markdown]
# ## Final reflection
#
# Do not write a long answer. A few precise sentences are enough.
#
# 1. Which exercise was easiest?
# 2. Which exercise forced you to think the most?
# 3. Did you make a mistake because of Python syntax, or because of the underlying logic?
# 4. Pick one piece of code from this notebook and explain what happens to the data from input to output.
# 5. What concept should the next practice reinforce?
